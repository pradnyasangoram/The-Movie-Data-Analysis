# %% [markdown]
# ## The Movie Dataset Analysis:
#
# ### ABOUT :
# The task is to answer few questions(exploratry data Analysis) about the dataset by coducting data-analysis using tools like jypyter notebooks, Python, Numpy,pandas, and Matplotlib. In order to make findings more interpretable
#
# #### Dataset: https://www.kaggle.com/tmdb/themoviedb.org -- Contains metadata on 5000 movies including cast, crew,budget, and revenue of each film.
#
# #### STEP 1: Data Wrangaling
# #### STEP 2:Exploratory Data Analysis:
#    ##### Q1. What are the highest grossing films of all the time?
#    ###### Q2. Which day of week has most number of releses?
#    ###### Q3. How does popularity influence revenue og a film?
#    ###### Q4. What is average voting of films among viewers?
# #### STEP 3: Conclusion
# #### STEP 4: Limitations

# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('TMDB Movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
# Checking unique values
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
#droping unnessary columns
df= df.drop(['id','imdb_id', 'homepage', 'tagline', 'keywords', 'overview', 'budget_adj', 'revenue_adj'], axis=1)

# %%
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# ...

# %%
# total null values
df.isnull().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# director                  44
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# dtype: int64

# %%
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# ...

# %%
df['budget'].fillna(df['budget'].mean(), inplace=True)
df['revenue'].fillna(df['revenue'].mean(), inplace=True)
# Dropping null/NaN values in rows using df.dropna() function
df.dropna(axis=0, inplace=True)

# %%
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# ...

# %%
# converting non-date data-type to date-type 
df['release_date'] = pd.to_datetime(df['release_date'])
df['release_year'] = pd.DatetimeIndex(df['release_year'])
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# ...

# %% [markdown]
# Expolatory Data Analysis:

# %% [markdown]
# ##### Q1. What are the highest grossing films of all the time?

# %%
fig, ax = plt.subplots(figsize= (12, 6))
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size'] = 12
high_gross = df.sort_values(by='revenue', ascending= False)[:10]
plt.bar(high_gross['original_title'], high_gross['revenue'])
plt.xlabel('Film')
plt.ylabel('Revenue')
plt.title('heighest Grossing Films of all time')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Avatar(2.78B) was highest grossing film of all time, followed by Star Wars(2.06B) and Titanic(1.84B).

# %% [markdown]
# ##### Q2. Which day of the week has most number of releases?

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size']=12
day_week = df['release_date'].dt.day_name()
day_week.value_counts().plot.bar()
plt.xticks(rotation=45)
plt.xlabel('Weekday')
plt.ylabel('Films')
plt.title('Most Films by Day of Week')
plt.show()

# %% [markdown]
# Friday seems to have most of the releases followed by thursday and wednesday.

# %% [markdown]
# ##### Q3. How does popularity influence revenue of a film?

# %%
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size']=12
df.plot(x='popularity', y='revenue', kind='scatter', figsize=(12,6))
plt.title('Popularity vs Revenue')
plt.show()

# %% [markdown]
# There is General positive correlation among popularity and revenue with few outliers.

# %% [markdown]
# ##### Q4: What does average voting among films look like?

# %%
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.size']=12
df.vote_average.plot(kind='hist', bins = 20, figsize = (12,6), title='Average Voting by Viewer')

# %% [markdown]
# In general viewers have rated the films in following range, with very few ratings above 8.

# %% [markdown]
# ## Conclusions
# ##### Some of the meaningful insights extracted from the above analysis of data include:
#
# ##### 1.Avatar is highest grossing film of all time, followed by Star Wars: Force Awakens and Titanic.
# ##### 2.Friday saw the most number of film releases, followed by Thursday based on the day of week.
# ##### 3.Popularity has a positive affect on the success of a given film or its commercial revenue.
# ##### 4.Average vote among various films is around 6.0, with very few films having vote higher than 8.0.

# %% [markdown]
# ## Limitations:
#
# ##### Extracted data may be incomplete, as there are several missing values. This affects its usability.(For example, missing values in columns like budget/revenue are replaced with their means).
# ##### Data collected above varies in quality and format. Many unique values appear in individual columns.(For example, cast/genres columns have lots of unique values seperated by '|' operator).
# ##### Such data needs lot of preprocessing before its ready for analysis. There may be incorect data types.(For example, release_date/release_year had to be transformed before using them in analysis).
# ##### Such inconsistencies, must be treated with caution until making important decisions as it may produce biases.
